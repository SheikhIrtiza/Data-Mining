# %%
# importing all the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data set
data=pd.read_csv('/diabetes - Copy (2).csv')

# %%
data.head()#prints the first 5 rows or records of the dataset
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.head(10)# prints the first 10 rows
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
data.head(15)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
data.tail()#prints the last 5 rows of dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#to check the dimension of the dataset we use
data.shape
# Out:
# (768, 9)

# %%
#MISSING VALUE DETECTION AND TREATEMENT
#The following values in a data set are considered to be missing values.
#1.Blank Values
#2.NaN
#3.null
#4.some continuous columns might have 0's to indicate missing data.

# %%
#Lets start by checking the count of the records in each column of the data set
#If the count of records is lesser than the total number of records that is 768, we can conclude that there

data.info() # for blank values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#to check for any null value in data set 
#count of records for all the columns is 768 this indicates there is no blank columns in the data set
#false indicates no null value 
#and True will indcate null values present in dataset
data.isna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
#any null value for any particular column. we use
data.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
#summation of null values use
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#since all the predictor columns are continuous in nature, there might be a chance that 0's in 
# these columns indicate missing data.

#Lets check the above claim.

data.describe() # total count of data set eg glucose is 0 which is impossible
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data['Glucose']
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
#we can replace 0's with NaN
#The records that have 0's in columns Glucose, Blood Pressure, Skin Thickness, Insulin and BMI will be replaced with NaN

from numpy import nan

data['Glucose']=data['Glucose'].replace(0,np.nan)

# %%
data['BloodPressure']=data['BloodPressure'].replace(0,np.nan)

# %%
data['SkinThickness']=data['SkinThickness'].replace(0,np.nan)

# %%
data['Insulin']=data['Insulin'].replace(0,np.nan)

# %%
data['BMI']=data['BMI'].replace(0,np.nan)

# %%
#Lets check if the above code has worked
data.head()
#All the 0's have been replaced by NaN
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
#Count if NaN values in the dataset
print(data.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
#As inferred colums glucose , bp, st,insulin and BMI have missing data.
#1. Glucose, BP and BMI have less number of missing data
#2. but skin thickness and insulin have a very high amount of missing data.
 ###Removing these missing data from the data set will result in information loss and it is not 
 ###advisible to remove  these records since we have only 768 records. Hence we will import these
 ### missing values with the median of their respective colums, since median is at least
 ### affectd by Outliers.

# %%
data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                29.0000
# Insulin                     125.0000
# BMI                          32.3000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
#importong mising values with their respectove columns median
data.fillna(data.median(), inplace=True)

# %%
data.head() # in its output skinthickness has been replaced
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Checking if the missing values have been imported
print(data.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Outlier Detection and Treatement
# Outliers are extreme values that deviate from other observations on data, they may indicate a variability in a measurement, experiment errors or a novelty.
#
# Boxplots are a great way of detecting outliers. Once the outliers have been detected, they can be imputed with the 5th and 95th percentiles

# %%
#Outlier detection using boxplots

plt.figure(figsize= (20,15))

plt.subplot(4,4,1)
sns.boxplot(data['Pregnancies'])

plt.subplot(4,4,2)
sns.boxplot(data['Glucose'])

plt.subplot(4,4,3)
sns.boxplot(data['BloodPressure'])

plt.subplot(4,4,4)
sns.boxplot(data['SkinThickness'])

plt.subplot(4,4,5)
sns.boxplot(data['Insulin'])

plt.subplot(4,4,6)
sns.boxplot(data['BMI'])

plt.subplot(4,4,7)
sns.boxplot(data['DiabetesPedigreeFunction'])

plt.subplot(4,4,8)
sns.boxplot(data['Age'])

##Dots in output shows the outlier
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **Apart from 'Glucose' all the other attributes show presence of outliers. These lower level and upper level outliers will be replaced by 5th and 95th percentile respectively**

# %% [markdown]
# IQR

# %% [markdown]
# The interquartile range(IQR) is a measure of variability, based on dividing a data set into quartiles. Quartiles divide a rank-ordered data set into four equal parts. The values that divide each part ar called the first , second and third quartiles; and they are denoted by Q1, Q2 and Q3 resp.

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url="https://www.wikihow.com/images/thumb/1/1c/Find-the-IQR-Step-1-Version-4.jpg/aid2913094-v4-728px-Find-the-IQR-Step-1-Version-4.jpg")
# Out:
# <img src="https://www.wikihow.com/images/thumb/1/1c/Find-the-IQR-Step-1-Version-4.jpg/aid2913094-v4-728px-Find-the-IQR-Step-1-Version-4.jpg"/>

# %% [markdown]
# **Numpy.clip() function is used to Clip (limit) the values in an array.**
# syntax:numpy.clip(a,a_min,a_max,out=None)
# Parameters:
# a:Array containing elements to clip.
# a_min:Minimum value.
# a_max:Maximum value.
# ->if None, clipping is not performed on lower interval edge. Not more than one of a_min and a_max may be none

# %%
data['Pregnancies']=data['Pregnancies'].clip(lower=data['Pregnancies'].quantile(0.05), upper=data['Pregnancies'].quantile(0.95))

# %%
data['BloodPressure']=data['BloodPressure'].clip(lower=data['BloodPressure'].quantile(0.05), upper=data['BloodPressure'].quantile(0.95))

# %%
data['SkinThickness']=data['SkinThickness'].clip(lower=data['SkinThickness'].quantile(0.05), upper=data['SkinThickness'].quantile(0.95))

# %%
data['Insulin']=data['Insulin'].clip(lower=data['Insulin'].quantile(0.05), upper=data['Insulin'].quantile(0.95))

# %%
data['BMI']=data['BMI'].clip(lower=data['BMI'].quantile(0.05), upper=data['BMI'].quantile(0.95))

# %%
data['DiabetesPedigreeFunction']=data['DiabetesPedigreeFunction'].clip(lower=data['DiabetesPedigreeFunction'].quantile(0.05), upper=data['DiabetesPedigreeFunction'].quantile(0.95))

# %%
data['Age']=data['Age'].clip(lower=data['Age'].quantile(0.05), upper=data['Age'].quantile(0.95))

# %%
#Lets visualise the boxplots after impuying the outliers
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(data['Pregnancies'])

plt.subplot(4,4,2)
sns.boxplot(data['Glucose'])

plt.subplot(4,4,3)
sns.boxplot(data['BloodPressure'])

plt.subplot(4,4,4)
sns.boxplot(data['SkinThickness'])

plt.subplot(4,4,5)
sns.boxplot(data['Insulin'])

plt.subplot(4,4,6)
sns.boxplot(data['BMI'])

plt.subplot(4,4,7)
sns.boxplot(data['DiabetesPedigreeFunction'])

plt.subplot(4,4,8)
sns.boxplot(data['Age'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# As we can see, there are still outliers in columns Glucose. Lets try to manipulating the percentile values.
data['Glucose']=data['Glucose'].clip(lower=data['Glucose'].quantile(0.7), upper=data['Glucose'].quantile(0.9))

# %%
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(data['Glucose'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Data Visualisation**

# %%
#Lets start by understanding the distribution diabetic Vs Non Diabetic patients in the data set.
sns.countplot(data['Outcome'])
#i outcome is 0 then patient is diabetic
#if o/c is 1 then patient is non dabetic
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# From the above plot we can infer that majority of the data consists of Non Diabetic patients. Lets try to understand the percentage of Diabeteic in the data set

# %%
total=float(len(data))
ax = sns.countplot(x="Outcome", data=data)
for p in ax.patches:
  height = p.get_height()
  ax.text(p.get_x()+p.get_width()/2.,
           height + 3,
           '{0:.0%}'.format(height/total),
          ha="center")

# %% [markdown]
# About 65% of the data contains records belonging Non Diabetic Patient. The data set has a class imbalance and migh have to be treated in future, during the model building stages.

# %% [markdown]
# Lets now plot a corr-plot(correlation plot). This plot will help us understand if there is multi colinearity in the data set.

# %%
f, ax = plt.subplots(figsize=(20,10))
corr = data.corr("pearson")
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool_), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax,annot=True)

# %% [markdown]
# From the above corr-plot, it can be inffered that there is no high multi-collinearity in the dataset.
# The correlation plot shows the relation between the parameters.
#    1.Glucose, Age ,BMI and Pregnancies are the most correlated parameters with the Outcome,
#    2.Insulin and DiabetesPedigreeFunction have little correlation with the outcoome.
#    3.BP and SkinThickness have tiny correlation with the outcome.
#    4.There is a little correlation between Age and Pregnancies, Insulin And SkinThickness, BMI and Skinthickness, Insulin and Glucose.

# %% [markdown]
# **A pair plot a pairwise relatioships in a dataset. The pairplot fxn creates a grid of Axes such that each variable i data will be shared i the y-axis across a single row and in the x-axis across a single column.**

# %%
#pair plot analysis
sns.pairplot(data,hue='Outcome',diag_kind='kde')

# %% [markdown]
# From the above pairplot.
#
#    1.we can infer that most of the predictor variables are weak predictors of outcome.
#
#    2.the kernal density plots(diagonal) suggests that the distribution for diabetic and non diabetic are very similar and are overlapping each other significantly, hence they won't be ablet to differentiate between a diabetic and non-diabetic patient.
#
#    3.The satterplots also suggest very poorly correlated data(data with not hidden pattenrn or corelationships). Hence models built on this data might not be able to identify any hidden patterns or might identify nonsense patterns
# i.e. patterns  that do not make sense.
#
#    4.The plot shows that there is some relatiships b/w parameters. Outcome is added as hue(variable in "data" to map plot aspects to different colors). We see that blue and orange dots are overlap.
#
#    5.Pregnancies and age have some kind of a linear line.
#
#    6.BP and age have little relation. Most of the aged people have Blood Pressure.
#
#    7.Insulin and Glucose have some relatioship.
